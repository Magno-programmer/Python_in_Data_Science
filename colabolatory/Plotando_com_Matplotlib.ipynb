# %% [markdown]
# # Matplotlib

# %%
from random import randrange, seed
import matplotlib.pyplot as plt

# %%
seed(11)

notas_matematicas = []

for nota in range(8):
  notas_matematicas.append(randrange(0, 11, 2))

notas_matematicas
# Out:
# [6, 8, 6, 6, 8, 8, 2, 2]

# %%
x = list(range(1, 9))
y = notas_matematicas

plt.plot(x, y, marker= 'o')
plt.title('Notas de Matemática')
plt.xlabel('Provas')
plt.ylabel('notas')
plt.yticks(range(0, 11, 2))
plt.grid()
plt.show()
