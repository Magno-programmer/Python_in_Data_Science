# %% [markdown]
# # Tipo em Lista

# %%
lista = ['carlos', 21, True, 'a']

def Tipos_para_lista():
  for element in lista:
    print(f'O elemento {element} da lista é do tipo:  ', type(element))

Tipos_para_lista()
# Out:
# O elemento carlos da lista é do tipo:   <class 'str'>
# O elemento 21 da lista é do tipo:   <class 'int'>
# O elemento True da lista é do tipo:   <class 'bool'>
# O elemento a da lista é do tipo:   <class 'str'>

# %% [markdown]
# # Sistemas de Imports

# %%
from random import randrange, seed  # Biblioteca importada para gerar números aleatórios.

# %%
seed(10)

# %%
randrange(1, 10) # Uso da biblioteca importada.
# Out:
# 1

# %%
notas_matematicas = []

# Criando uma sequência de números aleatórios usando a biblioteca importada.
for notas in range(8): 
  notas_matematicas.append(randrange(0, 10))

notas_matematicas
# Out:
# [6, 7, 9, 0, 3, 7, 7, 4]
